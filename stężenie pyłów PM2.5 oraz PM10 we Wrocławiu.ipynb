# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import numpy as np

df = pd.read_excel ('dane2.xlsx')
df
# Out:
#                     Data  PM25  PM10
# 0    2021-01-01 01:00:00  63.8  71.1
# 1    2021-01-01 02:00:00  37.5  39.7
# 2    2021-01-01 03:00:00  35.7  37.5
# 3    2021-01-01 04:00:00  37.0  39.0
# 4    2021-01-01 05:00:00  35.4  37.3
# ...                  ...   ...   ...
# 8777 2022-01-01 19:00:00  14.2  17.3
# 8778 2022-01-01 20:00:00  14.0  17.3
# 8779 2022-01-01 21:00:00   8.8  10.5
# 8780 2022-01-01 22:00:00  10.8  12.4
# 8781 2022-01-01 23:00:00  14.0  16.6
#
# [8782 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(df["Data"][:],df["PM25"][:])
plt.title("Stężenie pyłu zawieszonego typu PM 2.5 na rocznym horyzoncie czasowym")
plt.xlabel("Data")
plt.ylabel("stężenie pyłu")
sns.set_theme()

# %%
plt.figure(figsize=(20,10))
plt.plot(df["Data"][:],df["PM10"][:])
plt.title("Stężenie pyłu zawieszonego typu PM 10 na rocznym horyzoncie czasowym")
plt.xlabel("Data")
plt.ylabel("stężenie pyłu")
sns.set_theme()

# %%
maxPM25=max(df["PM25"])
minPM25=min(df["PM25"])
mediana=statistics.median(df["PM25"])
średnia= np.mean(df["PM25"])
print(f'minimum PM25 {minPM25}\nmaksimum PM25 {maxPM25}\nmediana PM25 {mediana}\nśrednia PM25 {średnia}')
# Out:
# minimum PM25 3.1
# maksimum PM25 146.4
# mediana PM25 14.2
# średnia PM25 18.162447160973354

# %%
maxPM10=max(df["PM10"])
minPM10=min(df["PM10"])
mediana10=statistics.median(df["PM10"])
średnia10= np.mean(df["PM10"])
print(f'minimum PM10 {minPM10}\nmaksimum PM10 {maxPM10}\nmediana PM10 {mediana10}\nśrednia PM10 {średnia10}')
# Out:
# minimum PM10 3.7
# maksimum PM10 222.5
# mediana PM10 28.200000000000003
# średnia PM10 25.643402262081626

# %%
df2=pd.read_excel ('dane1.xlsx')
df2
# Out:
#                     Data  PM25  PM10
# 0    2022-01-01 01:00:00  13.8  15.6
# 1    2022-01-01 02:00:00   7.1   7.9
# 2    2022-01-01 03:00:00   6.5   7.4
# 3    2022-01-01 04:00:00   7.7   8.8
# 4    2022-01-01 05:00:00   7.6   8.8
# ...                  ...   ...   ...
# 2130 2022-03-30 20:00:00   NaN   NaN
# 2131 2022-03-30 21:00:00   NaN   NaN
# 2132 2022-03-30 22:00:00   NaN   NaN
# 2133 2022-03-30 23:00:00   NaN   NaN
# 2134 2022-03-31 00:00:00   NaN   NaN
#
# [2135 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(df2["Data"][:],df2["PM25"][:])
plt.plot(df2["Data"][:],df2["PM10"][:])
plt.title("Stężenie pyłów zawieszonych w roku 2022")
plt.xlabel("Data")
plt.ylabel("stężenie pyłu")
plt.legend(["PM2.5","PM10"],loc="upper left",fontsize=15)
sns.set_theme()

# %%
plt.figure(figsize=(20,10))
plt.plot(df2["Data"][:],df2["PM10"][:])
plt.title("Stężenie pyłu zawieszonego typu PM 10 w roku 2022")
plt.xlabel("Data")
plt.ylabel("stężenie pyłu")
sns.set_theme()

# %%
maxPM25=max(df2["PM25"])
minPM25=min(df2["PM25"])
mediana=statistics.median(df2["PM25"])
średnia= np.mean(df2["PM25"])
print(f'minimum PM25 {minPM25}\nmaksimum PM25 {maxPM25}\nmediana PM25 {mediana}\nśrednia PM25 {średnia}')
# Out:
# minimum PM25 2.9
# maksimum PM25 142.0
# mediana PM25 5.3
# średnia PM25 22.24893717524799

# %%
maxPM10=max(df2["PM10"])
minPM10=min(df2["PM10"])
mediana10=statistics.median(df2["PM10"])
średnia10= np.mean(df2["PM10"])
print(f'minimum PM10 {minPM10}\nmaksimum PM10 {maxPM10}\nmediana PM10 {mediana10}\nśrednia PM10 {średnia10}')
# Out:
# minimum PM10 3.6
# maksimum PM10 566.0
# mediana PM10 8.0
# średnia PM10 32.99886632026449
